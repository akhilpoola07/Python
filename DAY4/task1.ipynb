# %%
records = [
    ('akhil',{'age':24,'place':'hyderabad'}),
    ('sai',{'age':30,'place':'bangalore'}),
    ('sumanth',{'age':28,'place':'chennai'})
]
for name, All_details in records:
    for details in All_details:
        if All_details['age'] >= 30 and All_details['place'] == "hyderabad":
            print(name)

# %% [markdown]
# write a program to cluculate sum and square using high order function

# %%
def fun1(a,b,square):
    sum = a+b
    print(sum)
    print(square(sum))
    print(square(a))
def fun2(n):
    return n**2
fun1(2,5,fun2)
# Out:
# 7
# 49
# 4

# %%
def square(a):
    return a*a
def cube(a):
    return a*a*a
def operate(nums,operation):
    print(operation.__name__)
    for i in nums:
        print(operation.__name__ + ":", operation(i))
nums = [1,2,3]
operate(nums,cube)
# Out:
# cube
# cube: 1
# cube: 8
# cube: 27
